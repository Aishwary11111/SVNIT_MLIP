# %%
from ultralytics import YOLO
import pandas as pd
import os

# Function for calculating predictions and saving the results as a csv output
# By default a csv file is generated with image name, predicted class, bounding boxes and confidence score for each image.
# When save_images_with_bounding_boxes=True Images with bounding boxes drawn are saved to runs/detect/predict*
# When save_bounding_boxes_as_text=True bounding box coordiantes are saved to runs/detect/predict2/labels
def prediction(test_data_directory,model_path="detection_model.pt", show_images_while_prediction=False,save_images_with_bounding_boxes=True,save_bounding_boxes_as_text=True ,iou=0.5):
    detection_model = YOLO(model_path)
    
    result_df = pd.DataFrame(columns=["Image Name", "Predicted Class", "Bounding Box Location", "Confidence Level"])

    for root, dirs, files in os.walk(test_data_directory):
        for file in files:
            path = root + file

            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff', '.bmp', '.gif')):
                # Initialising Result Row
                res_row = [file]
                
                detection_result = detection_model.predict(path,iou=iou, show=False, save=save_images_with_bounding_boxes, save_txt=save_bounding_boxes_as_text)
                detection_boxes = detection_result[0].boxes
                
                predicted_boxes = []
                confidence_for_all_boxes = []
        
                if detection_boxes:
                    for box in detection_boxes:
                        predicted_bounding_box = box.xyxy.flatten().tolist() # Predicted bounding box
                        box_confidence_score = box.conf.item()  # Prediction confidence score
                        predicted_boxes.append(predicted_bounding_box)
                        confidence_for_all_boxes.append(box_confidence_score)
                    res_row.append("Bleeding")
                    res_row.append(predicted_boxes)
                    res_row.append(confidence_for_all_boxes)
                else:
                    res_row.append("Non Bleeding")
                    res_row.append("")
                    res_row.append("")
                    
                result_df.loc[len(result_df)] = res_row
            result_df.to_csv("prediction_results.csv") # Specify result csv filename here

# %%
# Run the following line after specifying test image directory path as well as detection model path
prediction(test_data_directory='val_75/', model_path='detection_model.pt')
# Out:
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (636).png: 224x224 1 bleeding, 19.1ms
# Speed: 0.4ms preprocess, 19.1ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 1 label saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1265).png: 224x224 1 bleeding, 19.1ms
# Speed: 0.4ms preprocess, 19.1ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 2 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (202).png: 224x224 1 bleeding, 19.1ms
# Speed: 0.5ms preprocess, 19.1ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 3 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (968).png: 224x224 1 bleeding, 18.0ms
# Speed: 0.4ms preprocess, 18.0ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 4 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (12).png: 224x224 1 bleeding, 18.0ms
# Speed: 0.4ms preprocess, 18.0ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 5 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (997).png: 224x224 1 bleeding, 18.1ms
# Speed: 0.5ms preprocess, 18.1ms inference, 1.6ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 6 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (498).png: 224x224 1 bleeding, 17.7ms
# Speed: 0.4ms preprocess, 17.7ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 7 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1226).png: 224x224 1 bleeding, 17.7ms
# Speed: 0.4ms preprocess, 17.7ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 8 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (501).png: 224x224 1 bleeding, 17.8ms
# Speed: 0.5ms preprocess, 17.8ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 9 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (607).png: 224x224 1 bleeding, 14.1ms
# Speed: 0.4ms preprocess, 14.1ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 10 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (406).png: 224x224 1 bleeding, 14.2ms
# Speed: 0.4ms preprocess, 14.2ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 11 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (185).png: 224x224 1 bleeding, 14.3ms
# Speed: 0.8ms preprocess, 14.3ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 12 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (349).png: 224x224 1 bleeding, 14.1ms
# Speed: 0.4ms preprocess, 14.1ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 13 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (816).png: 224x224 1 bleeding, 14.1ms
# Speed: 0.4ms preprocess, 14.1ms inference, 1.8ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 14 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1288).png: 224x224 3 bleedings, 14.6ms
# Speed: 0.5ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 15 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1262).png: 224x224 1 bleeding, 13.9ms
# Speed: 0.4ms preprocess, 13.9ms inference, 1.6ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 16 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (194).png: 224x224 2 bleedings, 12.8ms
# Speed: 0.4ms preprocess, 12.8ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 17 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1136).png: 224x224 1 bleeding, 13.3ms
# Speed: 0.4ms preprocess, 13.3ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 18 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1048).png: 224x224 1 bleeding, 12.7ms
# Speed: 0.4ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 19 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (972).png: 224x224 1 bleeding, 12.6ms
# Speed: 0.4ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 20 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (646).png: 224x224 2 bleedings, 12.7ms
# Speed: 0.4ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 21 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (797).png: 224x224 1 bleeding, 12.7ms
# Speed: 0.5ms preprocess, 12.7ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 22 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (87).png: 224x224 1 bleeding, 12.5ms
# Speed: 0.4ms preprocess, 12.5ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 23 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1267).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 24 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (331).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 25 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (802).png: 224x224 2 bleedings, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 26 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (627).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 27 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (359).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 28 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (117).png: 224x224 1 bleeding, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 29 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (43).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.5ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 30 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (846).png: 224x224 2 bleedings, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 31 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (414).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 32 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1098).png: 224x224 2 bleedings, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 33 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (307).png: 224x224 2 bleedings, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 34 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (363).png: 224x224 3 bleedings, 11.9ms
# Speed: 0.5ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 35 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1086).png: 224x224 2 bleedings, 12.3ms
# Speed: 0.5ms preprocess, 12.3ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 36 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1228).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 37 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (508).png: 224x224 1 bleeding, 12.1ms
# Speed: 0.5ms preprocess, 12.1ms inference, 1.8ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 38 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (513).png: 224x224 2 bleedings, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 39 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (159).png: 224x224 2 bleedings, 11.8ms
# Speed: 0.5ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 40 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (424).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 41 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1038).png: 224x224 3 bleedings, 11.8ms
# Speed: 0.9ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 42 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (374).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 43 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1130).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 44 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1118).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.5ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 45 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (844).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.5ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 46 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1085).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 47 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (531).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.5ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 48 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (81).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.5ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 49 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1285).png: 224x224 2 bleedings, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 50 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (649).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 51 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (730).png: 224x224 1 bleeding, 12.2ms
# Speed: 0.4ms preprocess, 12.2ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 52 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (19).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 53 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (812).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 54 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (45).png: 224x224 (no detections), 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 54 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (182).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 55 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (700).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 56 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (84).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.5ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 57 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1200).png: 224x224 (no detections), 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 57 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (278).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.5ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 58 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1083).png: 224x224 2 bleedings, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 59 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (908).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 60 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1272).png: 224x224 2 bleedings, 12.1ms
# Speed: 0.5ms preprocess, 12.1ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 61 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (60).png: 224x224 1 bleeding, 11.7ms
# Speed: 0.4ms preprocess, 11.7ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 62 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (430).png: 224x224 3 bleedings, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 63 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (314).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 64 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (669).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 65 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (975).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 66 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (15).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 67 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (226).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 68 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1070).png: 224x224 2 bleedings, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 69 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (660).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 70 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (639).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 71 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1113).png: 224x224 2 bleedings, 11.7ms
# Speed: 0.4ms preprocess, 11.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 72 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (563).png: 224x224 2 bleedings, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 73 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1093).png: 224x224 3 bleedings, 12.0ms
# Speed: 0.4ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 74 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1003).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 75 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (141).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 76 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (517).png: 224x224 2 bleedings, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 77 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (377).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 78 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (931).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 79 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (170).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.7ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 80 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (865).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 81 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (387).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.5ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 82 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (77).png: 224x224 (no detections), 11.7ms
# Speed: 0.4ms preprocess, 11.7ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 82 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (371).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 83 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (770).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 84 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1146).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 85 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1234).png: 224x224 1 bleeding, 11.7ms
# Speed: 0.4ms preprocess, 11.7ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 86 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (768).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 87 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (257).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 88 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1142).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 89 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (61).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 90 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1251).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 91 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (27).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.6ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 92 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (584).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 93 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (409).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 94 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (814).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 95 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1264).png: 224x224 1 bleeding, 13.1ms
# Speed: 0.4ms preprocess, 13.1ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 96 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (497).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 97 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (427).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 98 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (568).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 99 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1110).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.5ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 100 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (456).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 101 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (50).png: 224x224 (no detections), 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 101 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (104).png: 224x224 1 bleeding, 11.7ms
# Speed: 0.4ms preprocess, 11.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 102 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (881).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 103 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1286).png: 224x224 (no detections), 12.1ms
# Speed: 0.4ms preprocess, 12.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 103 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (706).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 104 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (461).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 105 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (400).png: 224x224 1 bleeding, 12.0ms
# Speed: 0.4ms preprocess, 12.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 106 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (756).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 107 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (977).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.5ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 108 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (264).png: 224x224 2 bleedings, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 109 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (831).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.3ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 110 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (239).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 111 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1115).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 112 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (583).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 113 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (671).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 114 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1114).png: 224x224 1 bleeding, 12.0ms
# Speed: 0.5ms preprocess, 12.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 115 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (3).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 116 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (346).png: 224x224 1 bleeding, 11.7ms
# Speed: 0.4ms preprocess, 11.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 117 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (59).png: 224x224 1 bleeding, 12.0ms
# Speed: 0.4ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 118 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (150).png: 224x224 1 bleeding, 12.1ms
# Speed: 0.5ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 119 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1239).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 120 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (615).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 121 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (970).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.5ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 122 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (654).png: 224x224 1 bleeding, 11.7ms
# Speed: 0.4ms preprocess, 11.7ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 123 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (573).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 124 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1178).png: 224x224 1 bleeding, 11.7ms
# Speed: 0.4ms preprocess, 11.7ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 125 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (853).png: 224x224 2 bleedings, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 126 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1219).png: 224x224 2 bleedings, 11.8ms
# Speed: 0.5ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 127 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (713).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 128 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1302).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 129 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (912).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.5ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 130 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (580).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 131 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (383).png: 224x224 2 bleedings, 12.4ms
# Speed: 0.4ms preprocess, 12.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 132 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (955).png: 224x224 2 bleedings, 11.8ms
# Speed: 0.7ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 133 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1043).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 134 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (11).png: 224x224 (no detections), 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 134 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (455).png: 224x224 1 bleeding, 12.0ms
# Speed: 0.6ms preprocess, 12.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 135 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (505).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 136 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (187).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.3ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 137 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (245).png: 224x224 2 bleedings, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 138 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (222).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.7ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 139 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (130).png: 224x224 1 bleeding, 12.2ms
# Speed: 0.4ms preprocess, 12.2ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 140 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (549).png: 224x224 2 bleedings, 12.1ms
# Speed: 0.3ms preprocess, 12.1ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 141 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1260).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.3ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 142 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1292).png: 224x224 2 bleedings, 12.1ms
# Speed: 0.4ms preprocess, 12.1ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 143 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (947).png: 224x224 2 bleedings, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 144 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1213).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 145 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (364).png: 224x224 2 bleedings, 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 146 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (842).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.3ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 147 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (271).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 148 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (393).png: 224x224 1 bleeding, 12.0ms
# Speed: 0.4ms preprocess, 12.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 149 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (301).png: 224x224 2 bleedings, 12.0ms
# Speed: 0.4ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 150 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (230).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 151 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1120).png: 224x224 2 bleedings, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 152 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (416).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.3ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 153 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (521).png: 224x224 1 bleeding, 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 154 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1112).png: 224x224 2 bleedings, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 155 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (958).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.3ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 156 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1124).png: 224x224 2 bleedings, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 157 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (169).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.3ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 158 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (988).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 159 labels saved to runs/detect/predict3/labels
#
# ...
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 262 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (191).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 263 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1201).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 264 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (779).png: 224x224 2 bleedings, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 265 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (516).png: 224x224 2 bleedings, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 266 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (86).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 267 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (923).png: 224x224 1 bleeding, 12.0ms
# Speed: 0.4ms preprocess, 12.0ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 268 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (777).png: 224x224 2 bleedings, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 269 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (429).png: 224x224 2 bleedings, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 270 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (673).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 271 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (889).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 272 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (551).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 273 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (598).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 274 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1090).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 275 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (270).png: 224x224 1 bleeding, 12.0ms
# Speed: 0.4ms preprocess, 12.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 276 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (235).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 277 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1149).png: 224x224 2 bleedings, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 278 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (466).png: 224x224 1 bleeding, 12.0ms
# Speed: 0.4ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 279 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (862).png: 224x224 1 bleeding, 12.0ms
# Speed: 0.4ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 280 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (442).png: 224x224 1 bleeding, 12.1ms
# Speed: 0.7ms preprocess, 12.1ms inference, 1.7ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 281 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1105).png: 224x224 1 bleeding, 12.4ms
# Speed: 0.4ms preprocess, 12.4ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 282 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1184).png: 224x224 1 bleeding, 12.3ms
# Speed: 0.8ms preprocess, 12.3ms inference, 2.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 283 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (847).png: 224x224 2 bleedings, 12.3ms
# Speed: 0.4ms preprocess, 12.3ms inference, 1.8ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 284 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (458).png: 224x224 1 bleeding, 12.3ms
# Speed: 0.9ms preprocess, 12.3ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 285 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (991).png: 224x224 1 bleeding, 12.3ms
# Speed: 0.7ms preprocess, 12.3ms inference, 1.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 286 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1157).png: 224x224 (no detections), 12.4ms
# Speed: 0.5ms preprocess, 12.4ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 286 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (244).png: 224x224 2 bleedings, 12.4ms
# Speed: 0.4ms preprocess, 12.4ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 287 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1181).png: 224x224 3 bleedings, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 288 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1271).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 289 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (662).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 290 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (570).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.3ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 291 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1205).png: 224x224 1 bleeding, 12.4ms
# Speed: 0.4ms preprocess, 12.4ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 292 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (5).png: 224x224 (no detections), 11.8ms
# Speed: 0.3ms preprocess, 11.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 292 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (949).png: 224x224 2 bleedings, 11.9ms
# Speed: 0.9ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 293 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (866).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.5ms preprocess, 11.9ms inference, 1.7ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 294 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (296).png: 224x224 2 bleedings, 12.4ms
# Speed: 0.4ms preprocess, 12.4ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 295 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (460).png: 224x224 1 bleeding, 12.1ms
# Speed: 0.5ms preprocess, 12.1ms inference, 1.8ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 296 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1089).png: 224x224 1 bleeding, 12.9ms
# Speed: 0.8ms preprocess, 12.9ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 297 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (284).png: 224x224 1 bleeding, 12.6ms
# Speed: 0.6ms preprocess, 12.6ms inference, 1.7ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 298 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (279).png: 224x224 1 bleeding, 12.0ms
# Speed: 0.7ms preprocess, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 299 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (530).png: 224x224 1 bleeding, 12.2ms
# Speed: 0.4ms preprocess, 12.2ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 300 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1227).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 301 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (800).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 302 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (553).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 303 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (221).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.7ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 304 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (82).png: 224x224 2 bleedings, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 305 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (40).png: 224x224 2 bleedings, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 306 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (769).png: 224x224 2 bleedings, 12.1ms
# Speed: 0.4ms preprocess, 12.1ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 307 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (729).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 308 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1025).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 309 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (930).png: 224x224 1 bleeding, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 310 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (1138).png: 224x224 1 bleeding, 12.2ms
# Speed: 0.6ms preprocess, 12.2ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 311 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (550).png: 224x224 3 bleedings, 11.8ms
# Speed: 0.4ms preprocess, 11.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 312 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (528).png: 224x224 1 bleeding, 13.1ms
# Speed: 0.4ms preprocess, 13.1ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 313 labels saved to runs/detect/predict3/labels
#
# image 1/1 /home/ares/Desktop/MISAHUB_submission/git_repo/val_75/img- (181).png: 224x224 1 bleeding, 11.9ms
# Speed: 0.4ms preprocess, 11.9ms inference, 1.7ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 314 labels saved to runs/detect/predict3/labels
